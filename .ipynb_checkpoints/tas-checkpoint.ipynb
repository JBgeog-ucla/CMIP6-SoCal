# %% [markdown]
# # Tas notebook
# ### one variable + one realization: Import/open/subset/visualize
#
# ### Next challenge: join netcdfs with xarray, average values across xarray obj
# https://docs.xarray.dev/en/stable/user-guide/combining.html

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import cartopy
import cartopy.crs
import cartopy.feature as cfeature
import seaborn

# %%
import xarray as xr
import regionmask
import os
#this variable is only checked 
#at first import of GeoPandas.
#toggles on PYGEOS
#os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd

# %%
import earthpy 
import netCDF4 as nc
import cftime
#assists gpd with shp opening
import fiona #help(fiona.open)
import rasterio
import odc.geo.xr

# %%
#for clipping xarray 
import rioxarray as rio
from shapely.geometry import mapping
from shapely.geometry import Polygon

#for masking region
import seaborn as sns

# %%
#import h5netcdf
#import xmip as xmip
#import intake as intake
#import intake_esm as intake_esm
import rasterio
from affine import Affine
#import nc_time_axis
import cftime
from shapely.geometry import mapping, Polygon
import datetime
import warnings
from datetime import datetime, timedelta
#import regions
from osgeo import gdal,osr,ogr

# %%
#retrieving directory
os.getcwd()
#'/Users/jenniferbadger/Documents/GitHub/CMIP6-SoCal'
# Out:
# '/Users/jenniferbadger/Documents/GitHub/CMIP6-SoCal'

# %%
#os.chdir("/Users/jenniferbadger/Documents/GitHub/CMIP6-SoCal")

# %%
#creating path to CESM2 historical tas r4
path_tas_hist_r4 = "/Users/jenniferbadger/Dropbox/Climatology/Data_new/temp_hist/tas_Amon_CESM2_historical_r4i1p1f1_gn_185001-201412.nc"

# %%
#opening netcdf
tas_hist_r4 = nc.Dataset(path_tas_hist_r4)

# %%
#nc.Dataset(path_tas_hist_r4).close()

# %%
#retrieves metadata

#variable_id: tas
#frequency: mon
#experiment_id: historical
#nominal_resolution: 100 km = approx. hortizonal res
#realization_index: 4
#parent_time_units: days since 0001-01-01 00:00:00
print (tas_hist_r4)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.7 CMIP-6.2
#     activity_id: CMIP
#     case_id: 18
#     cesm_casename: b.e21.BHIST.f09_g17.CMIP6-historical.004
#     contact: cesm_cmip6@ucar.edu
#     creation_date: 2019-01-18T18:44:34Z
#     data_specs_version: 01.00.29
#     experiment: all-forcing simulation of the recent past
#     experiment_id: historical
#     external_variables: areacella
#     forcing_index: 1
#     frequency: mon
#     grid: native 0.9x1.25 finite volume grid (192x288 latxlon)
#     grid_label: gn
#     initialization_index: 1
#     institution: National Center for Atmospheric Research, Climate and Global Dynamics Laboratory, 1850 Table Mesa Drive, Boulder, CO 80305, USA
#     institution_id: NCAR
#     license: CMIP6 model data produced by <The National Center for Atmospheric Research> is licensed under a Creative Commons Attribution-[]ShareAlike 4.0 International License (https://creativecommons.org/licenses/). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file)[]. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law.
#     mip_era: CMIP6
#     model_doi_url: https://doi.org/10.5065/D67H1H0V
#     nominal_resolution: 100 km
#     parent_activity_id: CMIP
#     parent_experiment_id: piControl
#     parent_mip_era: CMIP6
#     parent_source_id: CESM2
#     parent_time_units: days since 0001-01-01 00:00:00
#     parent_variant_label: r1i1p1f1
#     physics_index: 1
#     product: model-output
#     realization_index: 4
#     realm: atmos
#     source: CESM2 (2017): atmosphere: CAM6 (0.9x1.25 finite volume grid; 288 x 192 longitude/latitude; 32 levels; top level 2.25 mb); ocean: POP2 (320x384 longitude/latitude; 60 levels; top grid cell 0-10 m); sea_ice: CICE5.1 (same grid as ocean); land: CLM5 0.9x1.25 finite volume grid; 288 x 192 longitude/latitude; 32 levels; top level 2.25 mb); aerosol: MAM4 (0.9x1.25 finite volume grid; 288 x 192 longitude/latitude; 32 levels; top level 2.25 mb); atmoschem: MAM4 (0.9x1.25 finite volume grid; 288 x 192 longitude/latitude; 32 levels; top level 2.25 mb); landIce: CISM2.1; ocnBgchem: MARBL (320x384 longitude/latitude; 60 levels; top grid cell 0-10 m)
#     source_id: CESM2
#     source_type: AOGCM BGC
#     table_id: Amon
#     tracking_id: hdl:21.14100/ef376c2e-c83b-4e73-a770-010e28bb1776
#     variable_id: tas
#     variant_info: CMIP6 20th century experiments (1850-2014) with CAM6, interactive land (CLM5), coupled ocean (POP2) with biogeochemistry (MARBL), interactive sea ice (CICE5.1), and non-evolving land ice (CISM2.1)
#
#     variant_label: r4i1p1f1
#     sub_experiment: none
#     sub_experiment_id: none
#     branch_time_in_parent: 182500.0
#     branch_time_in_child: 674885.0
#     branch_method: standard
#     further_info_url: https://furtherinfo.es-doc.org/CMIP6.NCAR.CESM2.historical.none.r4i1p1f1
#     dimensions(sizes): lat(192), nbnd(2), lon(288), time(1980)
#     variables(dimensions): float32 tas(time, lat, lon), float64 lat(lat), float64 lon(lon), float64 time(time), float64 time_bnds(time, nbnd), float32 lat_bnds(lat, nbnd), float32 lon_bnds(lon, nbnd)
#     groups:

# %%
#issues a warning but not an error
#xarray seems to work
tas_hist_r4 = xr.open_dataset(path_tas_hist_r4, decode_times= True, use_cftime= True, decode_coords="all")
# Out:
# /Users/jenniferbadger/opt/anaconda3/lib/python3.8/site-packages/xarray/conventions.py:551: SerializationWarning: variable 'tas' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /var/folders/19/knjb5nd52n90p_gwnf3k939c0000gn/T/ipykernel_14704/3448582648.py:3: UserWarning: Variable(s) referenced in cell_measures not in variables: ['areacella']
#   tas_hist_r4 = xr.open_dataset(path_tas_hist_r4, decode_times= True, use_cftime= True, decode_coords="all")

# %%
#more condensed metadata
print(tas_hist_r4)

#The specification seconds since 1992-10-8 15:15:42.5 -6:00 
#indicates seconds since October 8th, 1992 at 3 hours, 15 minutes and 42.5 seconds 
#in the afternoon in the time zone which is six hours to the west of 
#Coordinated Universal Time (i.e. Mountain Daylight Time). 
#The time zone specification can also be written without a colon 
#using one or two digits (indicating hours) 
#or three or four digits (indicating hours and minutes).
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1980, lat: 192, lon: 288, nbnd: 2)
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time       (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#     time_bnds  (time, nbnd) object ...
#     lat_bnds   (lat, nbnd) float32 ...
#     lon_bnds   (lon, nbnd) float32 ...
# Dimensions without coordinates: nbnd
# Data variables:
#     tas        (time, lat, lon) float32 ...
# Attributes: (12/45)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     case_id:                18
#     cesm_casename:          b.e21.BHIST.f09_g17.CMIP6-historical.004
#     contact:                cesm_cmip6@ucar.edu
#     creation_date:          2019-01-18T18:44:34Z
#     ...                     ...
#     sub_experiment:         none
#     sub_experiment_id:      none
#     branch_time_in_parent:  182500.0
#     branch_time_in_child:   674885.0
#     branch_method:          standard
#     further_info_url:       https://furtherinfo.es-doc.org/CMIP6.NCAR.CESM2.h...

# %%
#tas specific metada
#units:K
print(tas_hist_r4['tas'])
# Out:
# <xarray.DataArray 'tas' (time: 1980, lat: 192, lon: 288)>
# [109486080 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time     (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
# Attributes: (12/18)
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %%
#metadata again here under attributes
tas_hist_r4
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1980, lat: 192, lon: 288, nbnd: 2)
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time       (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#     time_bnds  (time, nbnd) object ...
#     lat_bnds   (lat, nbnd) float32 ...
#     lon_bnds   (lon, nbnd) float32 ...
# Dimensions without coordinates: nbnd
# Data variables:
#     tas        (time, lat, lon) float32 ...
# Attributes: (12/45)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     case_id:                18
#     cesm_casename:          b.e21.BHIST.f09_g17.CMIP6-historical.004
#     contact:                cesm_cmip6@ucar.edu
#     creation_date:          2019-01-18T18:44:34Z
#     ...                     ...
#     sub_experiment:         none
#     sub_experiment_id:      none
#     branch_time_in_parent:  182500.0
#     branch_time_in_child:   674885.0
#     branch_method:          standard
#     further_info_url:       https://furtherinfo.es-doc.org/CMIP6.NCAR.CESM2.h...

# %%
#shows time interval
tas_hist_r4.time.values

#see 4.4 time coordinate 
#for climate & forcasting conventions
#https://cfconventions.org/Data/cf-conventions/cf-conventions-1.10/cf-conventions.html
# Out:
# array([cftime.DatetimeNoLeap(1850, 1, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 2, 14, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1850, 3, 15, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeNoLeap(2014, 10, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 11, 15, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 15, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)

# %%
#-90 to 90 as expected
tas_hist_r4.lat_bnds.values
# Out:
# array([[-90.       , -89.52879  ],
#        [-89.52879  , -88.58639  ],
#        [-88.58639  , -87.64398  ],
#        [-87.64398  , -86.70157  ],
#        [-86.70157  , -85.75916  ],
#        [-85.75916  , -84.81676  ],
#        [-84.81676  , -83.874344 ],
#        [-83.874344 , -82.93194  ],
#        [-82.93194  , -81.98953  ],
#        [-81.98953  , -81.04712  ],
#        [-81.04712  , -80.10471  ],
#        [-80.10471  , -79.1623   ],
#        [-79.1623   , -78.219894 ],
#        [-78.219894 , -77.27749  ],
#        [-77.27749  , -76.335075 ],
#        [-76.335075 , -75.39267  ],
#        [-75.39267  , -74.450264 ],
#        [-74.450264 , -73.50785  ],
#        [-73.50785  , -72.565445 ],
#        [-72.565445 , -71.62304  ],
#        [-71.62304  , -70.680626 ],
#        [-70.680626 , -69.73822  ],
#        [-69.73822  , -68.795815 ],
#        [-68.795815 , -67.8534   ],
#        [-67.8534   , -66.910995 ],
#        [-66.910995 , -65.96859  ],
#        [-65.96859  , -65.02618  ],
#        [-65.02618  , -64.08377  ],
#        [-64.08377  , -63.14136  ],
#        [-63.14136  , -62.19895  ],
#        [-62.19895  , -61.256546 ],
#        [-61.256546 , -60.314137 ],
#        [-60.314137 , -59.371727 ],
#        [-59.371727 , -58.429317 ],
#        [-58.429317 , -57.48691  ],
#        [-57.48691  , -56.544502 ],
#        [-56.544502 , -55.602093 ],
#        [-55.602093 , -54.659687 ],
#        [-54.659687 , -53.717278 ],
#        [-53.717278 , -52.774868 ],
#        [-52.774868 , -51.832462 ],
#        [-51.832462 , -50.890053 ],
#        [-50.890053 , -49.947643 ],
#        [-49.947643 , -49.005234 ],
#        [-49.005234 , -48.062828 ],
#        [-48.062828 , -47.12042  ],
#        [-47.12042  , -46.17801  ],
#        [-46.17801  , -45.235603 ],
#        [-45.235603 , -44.293194 ],
#        [-44.293194 , -43.350784 ],
#        [-43.350784 , -42.40838  ],
#        [-42.40838  , -41.46597  ],
#        [-41.46597  , -40.52356  ],
#        [-40.52356  , -39.58115  ],
#        [-39.58115  , -38.638744 ],
#        [-38.638744 , -37.696335 ],
#        [-37.696335 , -36.753925 ],
#        [-36.753925 , -35.81152  ],
#        [-35.81152  , -34.86911  ],
#        [-34.86911  , -33.9267   ],
#        [-33.9267   , -32.984295 ],
#        [-32.984295 , -32.041885 ],
#        [-32.041885 , -31.099476 ],
#        [-31.099476 , -30.157068 ],
#        [-30.157068 , -29.214659 ],
#        [-29.214659 , -28.272251 ],
#        [-28.272251 , -27.329844 ],
#        [-27.329844 , -26.387434 ],
#        [-26.387434 , -25.445026 ],
#        [-25.445026 , -24.502617 ],
#        [-24.502617 , -23.56021  ],
#        [-23.56021  , -22.617802 ],
#        [-22.617802 , -21.675392 ],
#        [-21.675392 , -20.732985 ],
#        [334.375, 335.625],
#        [335.625, 336.875],
#        [336.875, 338.125],
#        [338.125, 339.375],
#        [339.375, 340.625],
#        [340.625, 341.875],
#        [341.875, 343.125],
#        [343.125, 344.375],
#        [344.375, 345.625],
#        [345.625, 346.875],
#        [346.875, 348.125],
#        [348.125, 349.375],
#        [349.375, 350.625],
#        [350.625, 351.875],
#        [351.875, 353.125],
#        [353.125, 354.375],
#        [354.375, 355.625],
#        [355.625, 356.875],
#        [356.875, 358.125],
#        [358.125, 359.375]], dtype=float32)

# %%
#For xarray datasets, .sel returns a new dataset 
#using a dimension shared by all of the datasets
#in the array, eg (time= specific entry I want to visualize)

#cftime decodes time units + variable values 
#in a netcdf conforming to Climate and Forecasting (CF) netCDF conventions
#https://unidata.github.io/cftime/api.html

#.plot uses matplotlib to visualize the dataset

#cftime.datetime(int year, int month, int day, int hour=0, 
#int minute=0, int second=0, int microsecond=0, 
#int dayofwk=-1, int dayofyr=-1)

#1850 = yr, #1 = Jan, 15=15th, 12,0,0,0= hour/min/sec/microsec
#2= integer day of week- Jan 15th, 1850= Tuesday
#15= integer day of year
tas_global_Jan1850 = tas_hist_r4['tas'].sel(time=cftime.DatetimeNoLeap(1850, 1, 15, 12, 0, 0, 0, 2, 15)).plot(cmap = 'coolwarm')

tas_global_Jan1850

#w/o #int dayofwk=-1, int dayofyr=-1
#yeilds same result

#could make extent with Google Earth Pro
#and use to subset

# %%
lat = tas_hist_r4.variables['lat'][:]
lon = tas_hist_r4.variables['lon'][:]

# %%
#So Cal counties shp
#from County of LA Enterprise GIS
#https://egis-lacounty.hub.arcgis.com/datasets/lacounty::county-boundaries/explore?location=33.969439%2C-118.754050%2C6.00
#for AOI construction

cali_county_shp = ("/Users/jenniferbadger/Dropbox/Climatology/Data_new/County_Boundaries.zip")

# %%
county_gdf = gpd.read_file(cali_county_shp)
county_gdf
# Out:
#     OBJECTID          TYPE                    NAME    ShapeSTAre  \
# 0         14  Other County             KERN COUNTY  2.254539e+11
# 1         15  Other County           ORANGE COUNTY  2.210048e+10
# 2         16  Other County        RIVERSIDE COUNTY  8.300114e+10
# 3         17  Other County   SAN BERNARDINO COUNTY  2.739830e+11
# 4         18  Other County        SAN DIEGO COUNTY  1.057717e+11
# 5         19  Other County  SAN LUIS OBISPO COUNTY  8.826784e+10
# 6         20  Other County    SANTA BARBARA COUNTY  7.665691e+10
# 7         21  Other County          VENTURA COUNTY  5.177124e+10
# 8         22     LA County      LOS ANGELES COUNTY  1.102047e+11
# 9         23     LA County      LOS ANGELES COUNTY  2.083714e+09
# 10        24     LA County      LOS ANGELES COUNTY  1.573226e+09
#
#       ShapeSTLen                                           geometry
# 0   2.297113e+06  MULTIPOLYGON (((-13094857.732 4271549.305, -13...
# 1   7.010162e+05  POLYGON ((-13126431.355 4021698.860, -13126430...
# 2   1.312613e+06  POLYGON ((-12942717.828 3952272.640, -12942869...
# 3   2.335592e+06  POLYGON ((-12941319.720 4033413.843, -12941393...
# 4   1.933786e+06  MULTIPOLYGON (((-12942717.828 3952272.640, -12...
# 5   2.013038e+06  POLYGON ((-13299646.133 4150459.185, -13300190...
# 6   2.246257e+06  MULTIPOLYGON (((-13299646.133 4150459.185, -13...
# 7   1.229728e+06  MULTIPOLYGON (((-13233732.749 4135263.477, -13...
# 8   2.284699e+06  MULTIPOLYGON (((-13106614.892 4139887.600, -13...
# 9   4.055774e+05  MULTIPOLYGON (((-13203038.399 3959049.207, -13...
# 10  3.575864e+05  MULTIPOLYGON (((-13201512.023 3899597.281, -13...

# %%
county_gdf.columns
# Out:
# Index(['OBJECTID', 'TYPE', 'NAME', 'ShapeSTAre', 'ShapeSTLen', 'geometry'], dtype='object')

# %%
#creating a list of Bight Counties
#this didn't work with isin
#bight_counties = ["SANTA BARBARA COUNTY", "VENTURA COUNTY", 
#"LOS ANGELES COUNTY", "ORANGE COUNTY", "SAN DIEGO COUNTY"]

# %%
#creating shp subset for AOI
bight_counties_aoi=county_gdf[county_gdf['NAME'].isin(["SANTA BARBARA COUNTY", "VENTURA COUNTY", "LOS ANGELES COUNTY", "ORANGE COUNTY", "SAN DIEGO COUNTY"])]

bight_counties_aoi
# Out:
#     OBJECTID          TYPE                  NAME    ShapeSTAre    ShapeSTLen  \
# 1         15  Other County         ORANGE COUNTY  2.210048e+10  7.010162e+05
# 4         18  Other County      SAN DIEGO COUNTY  1.057717e+11  1.933786e+06
# 6         20  Other County  SANTA BARBARA COUNTY  7.665691e+10  2.246257e+06
# 7         21  Other County        VENTURA COUNTY  5.177124e+10  1.229728e+06
# 8         22     LA County    LOS ANGELES COUNTY  1.102047e+11  2.284699e+06
# 9         23     LA County    LOS ANGELES COUNTY  2.083714e+09  4.055774e+05
# 10        24     LA County    LOS ANGELES COUNTY  1.573226e+09  3.575864e+05
#
#                                              geometry
# 1   POLYGON ((-13126431.355 4021698.860, -13126430...
# 4   MULTIPOLYGON (((-12942717.828 3952272.640, -12...
# 6   MULTIPOLYGON (((-13299646.133 4150459.185, -13...
# 7   MULTIPOLYGON (((-13233732.749 4135263.477, -13...
# 8   MULTIPOLYGON (((-13106614.892 4139887.600, -13...
# 9   MULTIPOLYGON (((-13203038.399 3959049.207, -13...
# 10  MULTIPOLYGON (((-13201512.023 3899597.281, -13...

# %%
bight_counties_aoi.drop([9,10], axis=0, inplace=True)
# Out:
# /var/folders/19/knjb5nd52n90p_gwnf3k939c0000gn/T/ipykernel_14704/573277902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bight_counties_aoi.drop([9,10], axis=0, inplace=True)

# %%
bight_counties_aoi
# Out:
#    OBJECTID          TYPE                  NAME    ShapeSTAre    ShapeSTLen  \
# 1        15  Other County         ORANGE COUNTY  2.210048e+10  7.010162e+05
# 4        18  Other County      SAN DIEGO COUNTY  1.057717e+11  1.933786e+06
# 6        20  Other County  SANTA BARBARA COUNTY  7.665691e+10  2.246257e+06
# 7        21  Other County        VENTURA COUNTY  5.177124e+10  1.229728e+06
# 8        22     LA County    LOS ANGELES COUNTY  1.102047e+11  2.284699e+06
#
#                                             geometry
# 1  POLYGON ((-13126431.355 4021698.860, -13126430...
# 4  MULTIPOLYGON (((-12942717.828 3952272.640, -12...
# 6  MULTIPOLYGON (((-13299646.133 4150459.185, -13...
# 7  MULTIPOLYGON (((-13233732.749 4135263.477, -13...
# 8  MULTIPOLYGON (((-13106614.892 4139887.600, -13...

# %%
bight_counties_aoi.crs
# Out:
# <Derived Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bight_counties_aoi.geometry
# Out:
# 1    POLYGON ((-13126431.355 4021698.860, -13126430...
# 4    MULTIPOLYGON (((-12942717.828 3952272.640, -12...
# 6    MULTIPOLYGON (((-13299646.133 4150459.185, -13...
# 7    MULTIPOLYGON (((-13233732.749 4135263.477, -13...
# 8    MULTIPOLYGON (((-13106614.892 4139887.600, -13...
# Name: geometry, dtype: geometry

# %%
#projecting shp to CA State Plane Zone 6
bight_counties_aoi = bight_counties_aoi.to_crs('EPSG:26946')

# %%
#chcking crs
bight_counties_aoi.crs
# Out:
# <Derived Projected CRS: EPSG:26946>
# Name: NAD83 / California zone 6
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - California - counties Imperial; Orange; Riverside; San Diego.
# - bounds: (-118.15, 32.53, -114.42, 34.08)
# Coordinate Operation:
# - name: SPCS83 California zone 6 (meters)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
bight_counties_aoi.boundary.plot(color='k')
# Out:
# <AxesSubplot: >

# %%
bight_counties_aoi.iloc[0]
# Out:
# OBJECTID                                                     15
# TYPE                                               Other County
# NAME                                              ORANGE COUNTY
# ShapeSTAre                                   22100480210.613281
# ShapeSTLen                                        701016.219095
# geometry      POLYGON ((1845928.1172258179 698690.6788062968...
# Name: 1, dtype: object

# %%
bight_counties_aoi.iloc[4]
# Out:
# OBJECTID                                                     22
# TYPE                                                  LA County
# NAME                                         LOS ANGELES COUNTY
# ShapeSTAre                                  110204668151.496094
# ShapeSTLen                                       2284698.514535
# geometry      MULTIPOLYGON (((1863770.1654286545 795637.3992...
# Name: 8, dtype: object

# %%
#this looks at the bounds
#of the bight shapefile
#array of #s that are not lat/lon
#this is due to the projection
#asociated with the shapefile
bight_counties_aoi.total_bounds
# Out:
# array([1595827.06438072,  539561.74676963, 1998473.69160888,
#         833412.29367095])

# %%
#in order to rectify, reproject to 4326
#EPSG:4326 = GCS that uses the WGS84 ellipsoid for lat/lon

#reprojecting to CRS that 
#can handle lat/lon
#for the - get_aoi below
bight_counties_aoi = bight_counties_aoi.to_crs("EPSG:4326")

# %%
bight_counties_LA = bight_counties_aoi.iloc[4]

# %%
#from https://www.earthdatascience.org/courses/use-data-open-source-python/hierarchical-data-formats-hdf/summarize-climate-data-by-season/

#makes a function to convert a gpd object
#to lat/lon extent

def get_aoi(shp, world=True):
    lon_lat = {}
    # Get lat min, max
    aoi_lat = [float(shp.total_bounds[1]), float(shp.total_bounds[3])]
    aoi_lon = [float(shp.total_bounds[0]), float(shp.total_bounds[2])]

    #formats for the 0-360 lon values
    if world:
        aoi_lon[0] = aoi_lon[0] + 360
        aoi_lon[1] = aoi_lon[1] + 360
    lon_lat["lon"] = aoi_lon
    lon_lat["lat"] = aoi_lat
    return lon_lat

# %%
#lat:-90 to 90
#lon: 0-360
bight_bounds = get_aoi(bight_counties_aoi, world = True)
bight_bounds
# Out:
# {'lon': [239.32789705243422, 243.73358756684988],
#  'lat': [32.52338130617983, 35.114524016854006]}

# %%
#divides xarray according to time slice
#and lat/lon slice
#Lat/lon slice is working
#returns 4680 values
Bight_tas = tas_hist_r4["tas"].sel(
    time=slice("1950-01-15", "2014-12-15"),
    lon=slice(bight_bounds["lon"][0], bight_bounds["lon"][1]),
    lat=slice(bight_bounds["lat"][0], bight_bounds["lat"][1]))
Bight_tas
# Out:
# <xarray.DataArray 'tas' (time: 780, lat: 2, lon: 3)>
# [4680 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float64 33.46 34.4
#   * lon      (lon) float64 240.0 241.2 242.5
#   * time     (time) object 1950-01-15 12:00:00 ... 2014-12-15 12:00:00
# Attributes: (12/18)
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %%
print("Time Period start:", Bight_tas.time.min().values)
print("Time Period end:", Bight_tas.time.max().values)
# Out:
# Time Period start: 1950-01-15 12:00:00
# Time Period end: 2014-12-15 12:00:00

# %%
bight_region = regionmask.from_geopandas(bight_counties_aoi,
                                         names="name",
                                         name="name")

# %%
#create the regionmask
#using aoi as WGS84
bight_mask = regionmask.mask_3D_geopandas(bight_counties_aoi,
                                         tas_hist_r4.lon,
                                          tas_hist_r4.lat)

# Mask the netcdf data
#Bight_tas is my sliced array
bight_tas_masked = Bight_tas.where(bight_mask)
bight_tas_masked.dims

#'time', 'lat', 'lon', 'region'
# Out:
# ('time', 'lat', 'lon', 'region')

# %%
Bight_tas.values.shape
# Out:
# (780, 2, 3)

# %%
bight_tas_masked.lat
#seems correct for So-CAl
#([33.455497, 34.397906])
# Out:
# <xarray.DataArray 'lat' (lat: 2)>
# array([33.455497, 34.397906])
# Coordinates:
#   * lat      (lat) float64 33.46 34.4
# Attributes:
#     axis:           Y
#     standard_name:  latitude
#     title:          Latitude
#     type:           double
#     units:          degrees_north
#     valid_max:      90.0
#     valid_min:      -90.0

# %%
bight_tas_masked.lon
#these coors are zero to 360
# Out:
# <xarray.DataArray 'lon' (lon: 3)>
# array([240.  , 241.25, 242.5 ])
# Coordinates:
#   * lon      (lon) float64 240.0 241.2 242.5
# Attributes:
#     axis:           X
#     standard_name:  longitude
#     title:          Longitude
#     type:           double
#     units:          degrees_east
#     valid_max:      360.0
#     valid_min:      0.0

# %%
bight_tas_masked.time #780
# Out:
# <xarray.DataArray 'time' (time: 780)>
# array([cftime.DatetimeNoLeap(1950, 1, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1950, 2, 14, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1950, 3, 15, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeNoLeap(2014, 10, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 11, 15, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 15, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 1950-01-15 12:00:00 ... 2014-12-15 12:00:00
# Attributes:
#     axis:           T
#     standard_name:  time
#     title:          time
#     type:           double

# %%
#bight_tas_masked_mean_time = bight_tas_masked.groupby('time.month').mean('time')

#4 arrays- mean averaged across seasons
bight_season_summary = bight_tas_masked.groupby(
    'time.season').mean()

#bight_tas_masked_mean_time.shape
#bight_tas_masked_mean_time.dims

bight_season_summary.dims
# Out:
# ('season', 'lat', 'lon', 'region')

# %%
bight_season_summary.season.values
# Out:
# array(['DJF', 'JJA', 'MAM', 'SON'], dtype=object)

# %%
#See http://meteo.unican.es/work/xarray_seminar/xArray_seminar.html
#Example 2 for grouping and averaging

#Also see this
#https://kpegion.github.io/Pangeo-at-AOES/examples/advanced-analysis.html
#use this to average across ensembles

# %%
#sns.set(font_scale=1.3)
#sns.set_style("white")


#bight_tas_mean_time = bight_tas_masked.groupby('time.season').mean('time')

#Error message says can only plot 1D or 2D

#da.squeeze().plot.imshow()

#Only 1d and 2d plots are supported for facets in xarray. 
#See the package `Seaborn` for more options.
bight_season_summary.plot(col='month', col_wrap=2, figsize=(10, 10))


#bight_tas_mean_time.dims

#plt.suptitle("Mean Temperature Across 1950- 2014 By Season in the SoCal Bight",
             #y=1.05)

#plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 13
#       1 #sns.set(font_scale=1.3)
#       2 #sns.set_style("white")
#       3
#    (...)
#      11 #Only 1d and 2d plots are supported for facets in xarray.
#      12 #See the package `Seaborn` for more options.
# ---> 13 bight_season_summary.plot(col='month', col_wrap=2, figsize=(10, 10))
#      16 #bight_tas_mean_time.dims
#      17
#      18 #plt.suptitle("Mean Temperature Across 1950- 2014 By Season in the SoCal Bight",
#      19              #y=1.05)
#      20
#      21 #plt.show()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/xarray/plot/accessor.py:46, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      44 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      45 def __call__(self, **kwargs) -> Any:
# ---> 46     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/xarray/plot/dataarray_plot.py:304, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     302 else:
#     303     if row or col or hue:
# --> 304         raise ValueError(
#     305             "Only 1d and 2d plots are supported for facets in xarray. "
#     306             "See the package `Seaborn` for more options."
#     307         )
#     308     plotfunc = hist
#     310 kwargs["ax"] = ax
#
# ValueError: Only 1d and 2d plots are supported for facets in xarray. See the package `Seaborn` for more options.

# %%
#close netcdf
#nc.Dataset(path_tas_hist_r4).close()

# %%
#tas_hist_r4 = rio.open_rasterio(path_tas_hist_r4)

# %%
#starting again with a newly sliced ds
#time slice is working. 

#divides xarray according to time slice 
#and 'tas' variable
tasr4_1950_2014 = tas_hist_r4["tas"].sel(
    time=slice("1950-01-15", "2014-12-15"))
    
tasr4_1950_2014 #65yrs = 780months
# Out:
# <xarray.DataArray 'tas' (time: 780, lat: 192, lon: 288)>
# [43130880 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time     (time) object 1950-01-15 12:00:00 ... 2014-12-15 12:00:00
# Attributes: (12/18)
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %%
#shows correct period...
print("Time Period start:", tasr4_1950_2014.time.min().values)
print("Time Period end:", tasr4_1950_2014.time.max().values)
# Out:
# Time Period start: 1950-01-15 12:00:00
# Time Period end: 2014-12-15 12:00:00

# %%
tasr4_1950_2014.dims
# Out:
# ('time', 'lat', 'lon')

# %%
tasr4_1950_2014.variable
# Out:
# <xarray.Variable (time: 780, lat: 192, lon: 288)>
# [43130880 values with dtype=float32]
# Attributes: (12/18)
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %%
#tasr4_1950_2014 = tasr4_1950_2014.squeeze().transpose('time', 'lat', 'lon')

#converting lon from 0-360 to -180 > +180
#tasr4_1950_2014.coords["x"] = ((tasr4_1950_2014.lon + 180) % 360) - 180


#this makes a dictionary-like container of 
#coordinate arrays; needed for the following
#set_spatial_dims
tasr4_1950_2014.coords["lon"] = tasr4_1950_2014.lon
tasr4_1950_2014.coords["lat"] = tasr4_1950_2014.lat
tasr4_1950_2014.coords["time"] = tasr4_1950_2014.time

# %%
#lat is -90 to 90
#lon is zero to 360
tasr4_1950_2014.coords
# Out:
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time     (time) object 1950-01-15 12:00:00 ... 2014-12-15 12:00:00

# %%
#allocating lon and lat as x and y
#b/c dims and coords need to have the same name
#needed for clipping
tasr4_1950_2014.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
#        330.  , 331.25, 332.5 , 333.75, 335.  , 336.25, 337.5 , 338.75,
#        340.  , 341.25, 342.5 , 343.75, 345.  , 346.25, 347.5 , 348.75,
#        350.  , 351.25, 352.5 , 353.75, 355.  , 356.25, 357.5 , 358.75])

# %%
#ca shapefile
CA_gdf = gpd.read_file("/Users/jenniferbadger/Dropbox/Climatology/Data_new/ca-state-boundary/CA_State_TIGER2016.shp", crs="epsg:3083")

# %%
#converting to WGS84 CRS for lat/lon
CA_gdf = CA_gdf.to_crs("EPSG:4326")

# %%
#now these look like lat/lon values
CA_gdf.geometry.values
# Out:
# <GeometryArray>
# [<MULTIPOLYGON (((-119.635 33.265, -119.636 33.273, -119.636 33.281, -119.635...>]
# Length: 1, dtype: geometry

# %%
CA_gdf
# Out:
#   REGION DIVISION STATEFP   STATENS GEOID STUSPS        NAME LSAD  MTFCC  \
# 0      4        9      06  01779778    06     CA  California   00  G4000
#
#   FUNCSTAT         ALAND       AWATER     INTPTLAT      INTPTLON  \
# 0        A  403501101370  20466718403  +37.1551773  -119.5434183
#
#                                             geometry
# 0  MULTIPOLYGON (((-119.63473 33.26545, -119.6363...

# %%
#writing CRS to xarray to match gdf
tasr4_1950_2014.rio.write_crs('EPSG:4326', inplace=True)
# Out:
# <xarray.DataArray 'tas' (time: 780, lat: 192, lon: 288)>
# [43130880 values with dtype=float32]
# Coordinates:
#   * lat          (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon          (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time         (time) object 1950-01-15 12:00:00 ... 2014-12-15 12:00:00
#     spatial_ref  int64 0
# Attributes: (12/18)
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %%
#lon conversion equation
tasr4_1950_2014.coords["lon"] = ((tasr4_1950_2014.coords['lon'] + 180) % 360) - 180
tasr4_1950_2014 = tasr4_1950_2014.sortby(["time", "lat", "lon"])

# %%
#tasr4_1950_2014["lon"] = tasr4_1950_2014["lon"] - 180

# %%
#now they are -180 to 180
tasr4_1950_2014.lon
# Out:
# <xarray.DataArray 'lon' (lon: 288)>
# array([-180.  , -178.75, -177.5 , ...,  176.25,  177.5 ,  178.75])
# Coordinates:
#   * lon          (lon) float64 -180.0 -178.8 -177.5 -176.2 ... 176.2 177.5 178.8
#     spatial_ref  int64 0

# %%
tasr4_1950_2014.coords
# Out:
# Coordinates:
#   * lat          (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon          (lon) float64 -180.0 -178.8 -177.5 -176.2 ... 176.2 177.5 178.8
#   * time         (time) object 1950-01-15 12:00:00 ... 2014-12-15 12:00:00
#     spatial_ref  int64 0

# %%
#same as before .sortby()
tasr4_1950_2014.dims
# Out:
# ('time', 'lat', 'lon')

# %%
clipped = tasr4_1950_2014.rename(lon="x", lat="y").rio.clip(CA_gdf.geometry.apply(mapping), CA_gdf.crs, all_touched=True)

#.mean() is being used to average across lat/lon
#clipped = tasr4_1950_2014.rio.clip(bight_counties_aoi.geometry.apply(mapping), 
                                   #bight_counties_aoi.crs, drop=False, invert=True)#.mean(dim=['lon','lat']).values

# %%
bight_counties_aoi
# Out:
#    OBJECTID          TYPE                  NAME    ShapeSTAre    ShapeSTLen  \
# 1        15  Other County         ORANGE COUNTY  2.210048e+10  7.010162e+05
# 4        18  Other County      SAN DIEGO COUNTY  1.057717e+11  1.933786e+06
# 6        20  Other County  SANTA BARBARA COUNTY  7.665691e+10  2.246257e+06
# 7        21  Other County        VENTURA COUNTY  5.177124e+10  1.229728e+06
# 8        22     LA County    LOS ANGELES COUNTY  1.102047e+11  2.284699e+06
#
#                                             geometry
# 1  POLYGON ((-117.91674 33.94708, -117.91673 33.9...
# 4  MULTIPOLYGON (((-116.26641 33.42815, -116.2832...
# 6  MULTIPOLYGON (((-119.47275 34.90117, -119.4628...
# 7  MULTIPOLYGON (((-118.88064 34.78914, -118.8804...
# 8  MULTIPOLYGON (((-117.73872 34.82325, -117.7342...

# %%
#this actually seems to work
#however, despite spatial extent correctly
#lining up with the shapefile extent
#need to confirm that this is actually CA
clipped.sel(time='2014-01-15').plot()
#23 degree farenheit in SB mtns
#44 degre farenheit near SD

# %%
clipped.x
# Out:
# <xarray.DataArray 'x' (x: 10)>
# array([-125.  , -123.75, -122.5 , -121.25, -120.  , -118.75, -117.5 , -116.25,
#        -115.  , -113.75])
# Coordinates:
#   * x            (x) float64 -125.0 -123.8 -122.5 ... -116.2 -115.0 -113.8
#     spatial_ref  int64 0
# Attributes:
#     axis:           X
#     long_name:      longitude
#     standard_name:  longitude
#     units:          degrees_east

# %%
clipped.y
# Out:
# <xarray.DataArray 'y' (y: 11)>
# array([32.513089, 33.455497, 34.397906, 35.340314, 36.282723, 37.225131,
#        38.167539, 39.109948, 40.052356, 40.994764, 41.937173])
# Coordinates:
#   * y            (y) float64 32.51 33.46 34.4 35.34 ... 39.11 40.05 40.99 41.94
#     spatial_ref  int64 0
# Attributes:
#     axis:           Y
#     standard_name:  latitude
#     title:          Latitude
#     type:           double
#     units:          degrees_north
#     valid_max:      90.0
#     valid_min:      -90.0
#     long_name:      latitude

# %%
#longitude degrees east is confusing x axis title
#may be from 0-360
#I think -lonE = lonW
#when checked against CA lat/lon map this is correct
fig, ax = plt.subplots(figsize=(10, 10))

clipped.sel(time='2014-01-15').plot(ax=ax)
bight_counties_aoi.plot(ax=ax, facecolor='none', edgecolor='black')
#in Jan the seas are warmer than the land
CA_gdf.plot(ax=ax, facecolor='none', edgecolor='white')
plt.title(label="CA Climate Jan 15th, 2014",
          fontsize=20,
          color="Black")
# Out:
# Text(0.5, 1.0, 'CA Climate Jan 15th, 2014')

# %%
CA_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#CRS match so not sure why
#SD County is
#hanging off the edge of CA
bight_counties_aoi.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bight_counties_aoi
# Out:
#    OBJECTID          TYPE                  NAME    ShapeSTAre    ShapeSTLen  \
# 1        15  Other County         ORANGE COUNTY  2.210048e+10  7.010162e+05
# 4        18  Other County      SAN DIEGO COUNTY  1.057717e+11  1.933786e+06
# 6        20  Other County  SANTA BARBARA COUNTY  7.665691e+10  2.246257e+06
# 7        21  Other County        VENTURA COUNTY  5.177124e+10  1.229728e+06
# 8        22     LA County    LOS ANGELES COUNTY  1.102047e+11  2.284699e+06
#
#                                             geometry
# 1  POLYGON ((-117.91674 33.94708, -117.91673 33.9...
# 4  MULTIPOLYGON (((-116.26641 33.42815, -116.2832...
# 6  MULTIPOLYGON (((-119.47275 34.90117, -119.4628...
# 7  MULTIPOLYGON (((-118.88064 34.78914, -118.8804...
# 8  MULTIPOLYGON (((-117.73872 34.82325, -117.7342...

# %%
bight_counties_aoi['geometry']
# Out:
# 1    POLYGON ((-117.91674 33.94708, -117.91673 33.9...
# 4    MULTIPOLYGON (((-116.26641 33.42815, -116.2832...
# 6    MULTIPOLYGON (((-119.47275 34.90117, -119.4628...
# 7    MULTIPOLYGON (((-118.88064 34.78914, -118.8804...
# 8    MULTIPOLYGON (((-117.73872 34.82325, -117.7342...
# Name: geometry, dtype: geometry

# %%
new_lon = clipped['x'] % 360

new_lon
# Out:
# <xarray.DataArray 'x' (x: 10)>
# array([235.  , 236.25, 237.5 , 238.75, 240.  , 241.25, 242.5 , 243.75,
#        245.  , 246.25])
# Coordinates:
#   * x            (x) float64 -125.0 -123.8 -122.5 ... -116.2 -115.0 -113.8
#     spatial_ref  int64 0

# %%
new_lon.values.min()
# Out:
# 235.0

# %%
new_lon.values.max()
# Out:
# 246.25

# %%
USA_city_pts = gpd.read_file("/Users/jenniferbadger/Dropbox/Climatology/Data_new/tufts-uscities11-shapefile/GISPORTAL_GISOWNER01_USCITIES11.shp", crs= "ESPG:4326")
USA_city_pts
# Out:
#        CITIESX020          FEATURE         NAME     POP_RANGE  POP_2000  \
# 0             1.0  Populated Place         Attu  Undetermined    -99999
# 1             2.0  Populated Place   Point Hope     0 - 9,999       757
# 2             3.0  Populated Place    Point Lay  Undetermined    -99999
# 3             4.0  Populated Place      Diomede     0 - 9,999       146
# 4             5.0  Populated Place      Gambell     0 - 9,999       649
# ...           ...              ...          ...           ...       ...
# 35427     35428.0  Populated Place       Aurora     0 - 9,999       720
# 35428     35429.0  Populated Place    Liverpool     0 - 9,999      2505
# 35429     35430.0  Populated Place       Athens     0 - 9,999      1695
# 35430     35431.0      County Seat  Lake George     0 - 9,999       985
# 35431     35432.0      County Seat      Newport     0 - 9,999      5005
#
#       FIPS55                      COUNTY   FIPS STATE STFIPS DISPLAY VERSION  \
# 0      04540  Aleutians West Census Area  02016    AK     02       1      03
# 1      61630         North Slope Borough  02185    AK     02       0      03
# 2      61700         North Slope Borough  02185    AK     02       1      03
# 3      19060            Nome Census Area  02180    AK     02       0      03
# 4      27640            Nome Census Area  02180    AK     02       0      03
# ...      ...                         ...    ...   ...    ...     ...     ...
# 35427  03188               Cayuga County  36011    NY     36       0      03
# 35428  42884             Onondaga County  36067    NY     36       0      03
# 35429  02902               Greene County  36039    NY     36       0      03
# 35430  40508               Warren County  36113    NY     36       0      03
# 35431  48850              Orleans County  50019    VT     50       0      03
#
#                           geometry
# 0       POINT (173.23460 52.93391)
# 1      POINT (-166.81107 68.34705)
# 2      POINT (-163.09290 69.72028)
# 3      POINT (-168.92511 65.74739)
# 4      POINT (-171.73927 63.77514)
# ...                            ...
# 35427   POINT (-76.70005 42.75400)
# 35428   POINT (-76.21548 43.10770)
# 35429   POINT (-73.81215 42.26101)
# 35430   POINT (-73.71913 43.42656)
# 35431   POINT (-72.21316 44.93099)
#
# [35432 rows x 13 columns]

# %%
#looking at rows associated with LA
USA_city_pts[(USA_city_pts['NAME'] == 'Los Angeles') & (USA_city_pts['FIPS'] == '06037')]
# Out:
#        CITIESX020      FEATURE         NAME              POP_RANGE  POP_2000  \
# 26534     26535.0  County Seat  Los Angeles  1,000,000 - 9,999,999   3694820
#
#       FIPS55              COUNTY   FIPS STATE STFIPS DISPLAY VERSION  \
# 26534  44000  Los Angeles County  06037    CA     06       0      03
#
#                           geometry
# 26534  POINT (-118.24369 34.05223)

# %%
#select row with index label 27205
#for some reason iloc isn't working here

#lat/lon for LA looks right
USA_city_pts.loc[[27205],'geometry'].plot(facecolor='red')
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(figsize=(5, 5))

clipped.sel(time='2014-01-15').plot(ax=ax)
bight_counties_aoi.plot(ax=ax, facecolor='none', edgecolor='black')
#in Jan the seas are warmer than the land
CA_gdf.plot(ax=ax, facecolor='none', edgecolor='white')
USA_city_pts.loc[[27205],'geometry'].plot(ax=ax, facecolor='red')

plt.title(label="CA Climate Jan 15th, 2014",
          fontsize=10,
          color="Black")
# Out:
# Text(0.5, 1.0, 'CA Climate Jan 15th, 2014')

# %%
USA_city_pts['lon'] = USA_city_pts['geometry'].x
USA_city_pts['lat'] = USA_city_pts['geometry'].y
USA_city_pts.loc[27205]
# Out:
# CITIESX020                                          27206.0
# FEATURE                                     Populated Place
# NAME                                             Long Beach
# POP_RANGE                                 250,000 - 499,999
# POP_2000                                             461522
# FIPS55                                                43000
# COUNTY                                   Los Angeles County
# FIPS                                                  06037
# STATE                                                    CA
# STFIPS                                                   06
# DISPLAY                                                   0
# VERSION                                                  03
# geometry      POINT (-118.18923187235299 33.76696014369571)
# lon                                             -118.189232
# lat                                                33.76696
# Name: 27205, dtype: object

# %%
#-118.189232

#only concerend with single point
if USA_city_pts['lon'].loc[27205] < 0:
    USA_city_pts['lon'] = 360 + USA_city_pts['lon']

# %%
USA_city_pts = gpd.GeoDataFrame(
    USA_city_pts, geometry=gpd.points_from_xy(USA_city_pts.lon, USA_city_pts.lat))

# %%
#index 0 city already had weird lat value
#LA looks right for 0 to 360
USA_city_pts.loc[27205]
# Out:
# CITIESX020                                       27206.0
# FEATURE                                  Populated Place
# NAME                                          Long Beach
# POP_RANGE                              250,000 - 499,999
# POP_2000                                          461522
# FIPS55                                             43000
# COUNTY                                Los Angeles County
# FIPS                                               06037
# STATE                                                 CA
# STFIPS                                                06
# DISPLAY                                                0
# VERSION                                               03
# geometry      POINT (241.810768127647 33.76696014369571)
# lon                                           241.810768
# lat                                             33.76696
# Name: 27205, dtype: object

# %%
USA_city_pts.loc[[27205],'geometry'].plot(facecolor='red')
# Out:
# <AxesSubplot: >

# %%
vmin= 270.0
vmax = 287.5

fig, ax = plt.subplots(figsize=(6,6))
tas_hist_r4['tas'].sel(time=cftime.DatetimeNoLeap(2014, 1, 15, 12, 0, 0, 0, 2, 15)).plot(ax=ax, xlim= (235, 250),
                                                                                         ylim=(30, 42), 
                                                                                         #sets max/min K
                                                                                         vmin= vmin, vmax=vmax)
USA_city_pts.loc[[27205],'geometry'].plot(ax = ax, facecolor='red')
# Out:
# <AxesSubplot: title={'center': 'time = 2014-01-15 12:00:00'}, xlabel='longitude [degrees_east]', ylabel='latitude [degrees_north]'>

# %%
fig, ax = plt.subplots(figsize=(6 ,6))

clipped.sel(time='2014-01-15').plot(ax=ax)
bight_counties_aoi.plot(ax=ax, facecolor='none', edgecolor='black')
#in Jan the seas are warmer than the land
CA_gdf.plot(ax=ax, facecolor='none', edgecolor='white')
plt.title(label="CA Climate Jan 15th, 2014",
          fontsize=12,
          color="Black")
# Out:
# Text(0.5, 1.0, 'CA Climate Jan 15th, 2014')

# %%
#In July the seas are cooler than the land
clipped.sel(time='2014-07-15').plot()
#69 degree farenheit in SB mtns
#82 degre farenheit near SD

# %%
clipped.dims
# Out:
# ('time', 'y', 'x')

# %%
clipped.time
# Out:
# <xarray.DataArray 'time' (time: 780)>
# array([cftime.DatetimeNoLeap(1950, 1, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1950, 2, 14, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1950, 3, 15, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeNoLeap(2014, 10, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 11, 15, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2014, 12, 15, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time         (time) object 1950-01-15 12:00:00 ... 2014-12-15 12:00:00
#     spatial_ref  int64 0
# Attributes:
#     axis:           T
#     standard_name:  time
#     title:          time
#     type:           double

# %%
#4 seasons
#DJF=Dec-Feb
#MAM=Mar-May
#JJA=Jun-Aug
#SON=Sep-Nov

#Datetime components of the time dimension
#can be accessed directly & used for selecting & grouping.
clipped_mam = clipped.sel(time=clipped.time.dt.season=="MAM")

#calculate mean per year
#returns 65 year slices
clipped_mam.groupby(clipped_mam.time.dt.year).mean("time")

#but would be better to get historical average
# Out:
# <xarray.DataArray 'tas' (year: 65, y: 11, x: 10)>
# array([[[      nan,       nan,       nan, ..., 292.25778, 293.95764,
#                nan],
#         [      nan,       nan,       nan, ..., 291.63394, 294.22733,
#                nan],
#         [      nan,       nan,       nan, ..., 291.36902, 293.01645,
#          292.04092],
#         ...,
#         [285.3028 , 285.28137, 284.55386, ...,       nan,       nan,
#                nan],
#         [284.71277, 284.106  , 282.84537, ...,       nan,       nan,
#                nan],
#         [284.32016, 283.56665, 281.77487, ...,       nan,       nan,
#                nan]],
#
#        [[      nan,       nan,       nan, ..., 291.564  , 293.20972,
#                nan],
#         [      nan,       nan,       nan, ..., 291.00708, 293.38562,
#                nan],
#         [      nan,       nan,       nan, ..., 290.79553, 292.10245,
#          290.99374],
# ...
#         [285.95844, 286.96756, 286.37802, ...,       nan,       nan,
#                nan],
#         [285.4288 , 285.88412, 285.09354, ...,       nan,       nan,
#                nan],
#         [285.05588, 285.2455 , 284.19144, ...,       nan,       nan,
#                nan]],
#
#        [[      nan,       nan,       nan, ..., 291.81836, 294.0608 ,
#                nan],
#         [      nan,       nan,       nan, ..., 291.41284, 294.35867,
#                nan],
#         [      nan,       nan,       nan, ..., 291.72232, 293.3359 ,
#          291.71854],
#         ...,
#         [284.42786, 286.75952, 286.86545, ...,       nan,       nan,
#                nan],
#         [283.9641 , 285.34033, 285.13437, ...,       nan,       nan,
#                nan],
#         [283.58707, 284.0446 , 283.22357, ...,       nan,       nan,
#                nan]]], dtype=float32)
# Coordinates:
#   * y            (y) float64 32.51 33.46 34.4 35.34 ... 39.11 40.05 40.99 41.94
#   * x            (x) float64 -125.0 -123.8 -122.5 ... -116.2 -115.0 -113.8
#     spatial_ref  int64 0
#   * year         (year) int64 1950 1951 1952 1953 1954 ... 2011 2012 2013 2014
# Attributes: (12/18)
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %%
clipped_mam.mean("time")
# Out:
# <xarray.DataArray 'tas' (y: 11, x: 10)>
# array([[      nan,       nan,       nan,       nan,       nan, 288.90878,
#         288.7868 , 292.05136, 293.85797,       nan],
#        [      nan,       nan,       nan,       nan, 288.28186, 288.7365 ,
#         288.86505, 291.54077, 294.22018,       nan],
#        [      nan,       nan,       nan, 287.52927, 288.58224, 289.6732 ,
#         290.0932 , 291.52176, 293.11203, 291.94394],
#        [      nan,       nan,       nan, 287.40207, 288.2254 , 288.62216,
#         289.0119 , 290.96573, 291.6549 ,       nan],
#        [      nan,       nan, 286.83118, 287.1956 , 287.54343, 286.68756,
#         286.90207, 289.75497,       nan,       nan],
#        [      nan,       nan, 287.0016 , 287.542  , 285.29495, 283.8562 ,
#         285.05075,       nan,       nan,       nan],
#        [      nan, 286.31546, 287.46796, 287.67313, 284.21237, 282.03085,
#               nan,       nan,       nan,       nan],
#        [      nan, 285.7629 , 286.63434, 285.05667, 283.00793,       nan,
#               nan,       nan,       nan,       nan],
#        [284.91898, 285.81116, 285.2958 , 284.38065, 282.5909 ,       nan,
#               nan,       nan,       nan,       nan],
#        [284.36185, 284.5243 , 283.6501 , 282.6644 , 281.6719 ,       nan,
#               nan,       nan,       nan,       nan],
#        [283.9645 , 283.72894, 282.256  , 280.914  , 280.6753 ,       nan,
#               nan,       nan,       nan,       nan]], dtype=float32)
# Coordinates:
#   * y            (y) float64 32.51 33.46 34.4 35.34 ... 39.11 40.05 40.99 41.94
#   * x            (x) float64 -125.0 -123.8 -122.5 ... -116.2 -115.0 -113.8
#     spatial_ref  int64 0

# %%
fig, ax = plt.subplots(figsize=(6 ,6))

clipped_mam.mean("time").plot(ax=ax)
bight_counties_aoi.plot(ax=ax, facecolor='none', edgecolor='black')
#in Jan the seas are warmer than the land
CA_gdf.plot(ax=ax, facecolor='none', edgecolor='white')
plt.title(label="CA Mean Temp: March-May 1850- 2014",
          fontsize=12,
          color="Black")
# Out:
# Text(0.5, 1.0, 'CA Mean Temp: March-May 1850- 2014')

# %%
#this seems to also work to return the mean per season
#across the whol historical period
hist_clipped = clipped.groupby('time.season').mean('time')
hist_clipped
# Out:
# <xarray.DataArray 'tas' (season: 4, y: 11, x: 10)>
# array([[[      nan,       nan,       nan,       nan,       nan,
#          288.55383, 287.8593 , 286.4377 , 286.53473,       nan],
#         [      nan,       nan,       nan,       nan, 287.64453,
#          287.46085, 286.02963, 284.94504, 286.1664 ,       nan],
#         [      nan,       nan,       nan, 286.8169 , 286.0821 ,
#          284.7137 , 282.76776, 283.13974, 284.10474, 283.1631 ],
#         [      nan,       nan,       nan, 285.82916, 283.9886 ,
#          281.84174, 280.67197, 281.7188 , 282.10388,       nan],
#         [      nan,       nan, 285.73764, 284.73544, 282.51752,
#          279.34174, 278.18878, 279.85272,       nan,       nan],
#         [      nan,       nan, 285.1031 , 283.08627, 279.56372,
#          275.6497 , 275.14282,       nan,       nan,       nan],
#         [      nan, 285.02325, 283.7318 , 282.23608, 277.14975,
#          272.88943,       nan,       nan,       nan,       nan],
#         [      nan, 283.97943, 281.4087 , 279.24124, 275.33026,
#                nan,       nan,       nan,       nan,       nan],
#         [284.31412, 281.47147, 279.35968, 277.16476, 274.0185 ,
#                nan,       nan,       nan,       nan,       nan],
#         [283.58182, 280.24606, 276.9223 , 274.42825, 272.35468,
#                nan,       nan,       nan,       nan,       nan],
# ...
#          293.02777, 293.66415, 295.28354, 297.3814 ,       nan],
#         [      nan,       nan,       nan, 290.60007, 292.68976,
#          294.31412, 293.359  , 294.2039 , 295.53918, 294.82358],
#         [      nan,       nan,       nan, 290.71704, 292.9627 ,
#          292.5446 , 291.63773, 293.09888, 293.72675,       nan],
#         [      nan,       nan, 289.53268, 290.82178, 292.52097,
#          290.0479 , 289.6016 , 291.58594,       nan,       nan],
#         [      nan,       nan, 289.8038 , 292.18735, 290.3772 ,
#          286.97617, 287.182  ,       nan,       nan,       nan],
#         [      nan, 288.87076, 291.33252, 291.60123, 287.4614 ,
#          285.03174,       nan,       nan,       nan,       nan],
#         [      nan, 288.49564, 290.84824, 289.5277 , 286.11777,
#                nan,       nan,       nan,       nan,       nan],
#         [287.44473, 288.4324 , 288.93613, 287.0112 , 285.0745 ,
#                nan,       nan,       nan,       nan,       nan],
#         [287.01593, 287.00522, 286.11887, 284.8589 , 283.9747 ,
#                nan,       nan,       nan,       nan,       nan],
#         [286.68356, 286.13895, 284.4957 , 283.09674, 282.90735,
#                nan,       nan,       nan,       nan,       nan]]],
#       dtype=float32)
# Coordinates:
#   * y            (y) float64 32.51 33.46 34.4 35.34 ... 39.11 40.05 40.99 41.94
#   * x            (x) float64 -125.0 -123.8 -122.5 ... -116.2 -115.0 -113.8
#     spatial_ref  int64 0
#   * season       (season) object 'DJF' 'JJA' 'MAM' 'SON'
# Attributes: (12/18)
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %%
hist_clipped.plot(col='season', col_wrap=2, figsize=(10, 10))

plt.suptitle("CA Mean Temp per Season 1850- 2014",
             y=1.05, fontsize=20,
          color="Black")

plt.show()

# %%
from rasterio.plot import show

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

clipped_mam.mean("time").plot(ax=axs[0, 0], cmap='coolwarm')
axs[0, 0].set_title('MAM')

CA_gdf.plot(ax=axs[0, 0], facecolor= 'none', edgecolor = 'white')
bight_counties_aoi.plot(ax=axs[0, 0], facecolor='none', edgecolor='black')

#coherence[1].plot(ax=axs[0, 1], cmap='viridis')
#axs[0, 1].set_title('HV')

#coherence[2].plot(ax=axs[1, 0], cmap='viridis')
#axs[1, 0].set_title('VH')

#coherence[3].plot(ax=axs[1, 1], cmap='viridis')
#axs[1, 1].set_title('VV')

fig.suptitle('CA Mean Temp per Season 1850- 2014',  y=1.05, fontsize=20,
          color="Black")

plt.show()

#CA_gdf.plot(ax=p2, facecolor= 'none')
#CA_gdf.plot(ax=p3, facecolor= 'none')
#CA_gdf.plot(ax=p4, facecolor= 'none')

# %%
#This is for one year but you can change the time interval to days, months, weeks, etc. 

#hist_clipped = clipped.resample(time = '780M').sum() 

#hist_clipped
#hist_clipped.groupby('time').sum().plot()
# Out:
# <xarray.DataArray 'tas' (time: 2, y: 11, x: 10)>
# array([[[     0.     ,      0.     ,      0.     ,      0.     ,
#               0.     ,    288.22763,    287.48224,    285.84714,
#             285.59363,      0.     ],
#         [     0.     ,      0.     ,      0.     ,      0.     ,
#             287.38983,    287.13657,    285.618  ,    284.32858,
#             285.1461 ,      0.     ],
#         [     0.     ,      0.     ,      0.     ,    286.5414 ,
#             285.99594,    284.5524 ,    282.30957,    282.32123,
#             282.9309 ,    281.63745],
#         [     0.     ,      0.     ,      0.     ,    285.64532,
#             283.81738,    281.49173,    279.98825,    280.5841 ,
#             280.49484,      0.     ],
#         [     0.     ,      0.     ,    285.72906,    284.5667 ,
#             282.46664,    278.9817 ,    277.20258,    278.31146,
#               0.     ,      0.     ],
#         [     0.     ,      0.     ,    285.158  ,    283.03772,
#             279.27393,    274.4607 ,    273.1565 ,      0.     ,
#               0.     ,      0.     ],
#         [     0.     ,    285.2131 ,    283.81262,    281.76953,
#             276.4219 ,    271.7364 ,      0.     ,      0.     ,
# ...
#          225713.6    , 224685.16   , 224648.81   , 226507.61   ,
#               0.     ,      0.     ],
#         [     0.     ,      0.     , 224457.23   , 225594.6    ,
#          224275.53   , 222460.02   , 222971.56   ,      0.     ,
#               0.     ,      0.     ],
#         [     0.     , 223909.28   , 225306.97   , 225635.86   ,
#          222796.36   , 220923.94   ,      0.     ,      0.     ,
#               0.     ,      0.     ],
#         [     0.     , 223591.2    , 224930.11   , 223905.86   ,
#          221821.66   ,      0.     ,      0.     ,      0.     ,
#               0.     ,      0.     ],
#         [222903.48   , 223697.47   , 223881.39   , 222814.6    ,
#          221311.1    ,      0.     ,      0.     ,      0.     ,
#               0.     ,      0.     ],
#         [222550.8    , 222666.05   , 222234.95   , 221326.31   ,
#          220565.08   ,      0.     ,      0.     ,      0.     ,
#               0.     ,      0.     ],
#         [222287.67   , 221930.28   , 220971.75   , 219916.66   ,
#          219762.95   ,      0.     ,      0.     ,      0.     ,
#               0.     ,      0.     ]]], dtype=float32)
# Coordinates:
#   * y            (y) float64 32.51 33.46 34.4 35.34 ... 39.11 40.05 40.99 41.94
#   * x            (x) float64 -125.0 -123.8 -122.5 ... -116.2 -115.0 -113.8
#     spatial_ref  int64 0
#   * time         (time) object 1950-01-31 00:00:00 2015-01-31 00:00:00
# Attributes: (12/18)
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Near-Surface Air Temperature
#     type:           real
#     units:          K
#     variable_id:    tas

# %% [markdown]
# First try this:https://gis.stackexchange.com/questions/354782/masking-netcdf-time-series-data-from-shapefile-using-python
#
# Here is an example of using rioxarray to mask out data with a shapefile: https://corteva.github.io/rioxarray/stable/examples/clip_geom.html
#
# import geopandas
# import rioxarray
# import xarray
# from shapely.geometry import mapping
#
#
# MSWEP_monthly2 = xarray.open_dataarray('D:\G3P\DATA\Models\MSWEP\MSWEP_monthly.nc4')
# MSWEP_monthly2.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
# MSWEP_monthly2.rio.write_crs("epsg:4326", inplace=True)
# Africa_Shape = geopandas.read_file('D:\G3P\DATA\Shapefile\Africa_SHP\Africa.shp', crs="epsg:4326")
#
# clipped = MSWEP_monthly2.rio.clip(Africa_Shape.geometry.apply(mapping), Africa_Shape.crs, drop=False)

# %%
#try this first
#https://gis.stackexchange.com/questions/357490/mask-xarray-dataset-using-a-shapefile

#Read this article and consider re-opening dataset
#with rioxarray as it may be transposed using xarray
#https://medium.com/axionable-ai-and-blockchain/tips-to-handle-climate-data-with-python-702898e500db


#also see here for slicing to extent
#may be better to slice before projecting?
